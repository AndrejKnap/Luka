# %% [markdown]
# # Luka Dončić: analiza celotne NBA-kariere
#
# Interaktivna analiza vseh sezon od 2018/19 do 2025/26, primerjava s povprečjem lige in uradno peterico **All‑NBA First Team 2025/26**.
#
# Izberite **Runtime → Run all**. Zvezek naloži preverjeni podatkovni posnetek iz tega repozitorija in ustvari Plotly grafe v temnem načinu ter datoteko `luka_dashboard.html`.

# %%
# Namesti odvisnosti ter naloži in zaženi program iz istega repozitorija.
# %pip -q install plotly pandas numpy requests jinja2
import requests

SCRIPT_URL = 'https://raw.githubusercontent.com/AndrejKnap/Luka/main/luka_analysis.py'
response = requests.get(SCRIPT_URL, timeout=30)
response.raise_for_status()
exec(compile(response.text, SCRIPT_URL, 'exec'), {'__name__': '__main__'})

# %% [markdown]
# ## Metodologija in viri
#
# - Statistika igralcev: NBA.com, ESPN in Basketball Reference; podatkovni posnetek po zaključku redne sezone 2025/26.
# - *Pet najboljših*: uradna peterica All‑NBA First Team 2025/26 — Luka Dončić, Shai Gilgeous‑Alexander, Nikola Jokić, Victor Wembanyama in Cade Cunningham.
# - Povprečje lige: skupna produkcija povprečne ekipe je preračunana na Lukove minute posamezne sezone. Tako ne primerjamo njegovega 35-minutnega nastopa s 48-minutno ekipno vsoto.
# - TS% je ocena `PTS / (2 × (FGA + 0,44 × FTA))`.
#
# Viri: [NBA profil](https://www.nba.com/player/1629029/luka-doncic), [uradni All‑NBA izbor](https://www.nba.com/news/2025-26-all-nba-teams-announced), [ESPN statistika](https://www.espn.com/nba/player/stats/_/id/3945274/luka-doncic), [Basketball Reference](https://www.basketball-reference.com/players/d/doncilu01.html).
